# %% [markdown]
# ## Predictive Analysis
# -----
# -----

# %% [markdown]
# ### About the Dataset:
#
# The [Boston Housing Dataset](https://github.com/coder-d-Eyeden/predictive_ana_health/blob/main/diabetes.csv) is  derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - **CRIM** - per capita crime rate by town
# - **ZN** - proportion of residential land zoned for lots over 25,000 sq.ft.
# - **INDUS** - proportion of non-retail business acres per town.
# - **CHAS** - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - **NOX** - nitric oxides concentration (parts per 10 million)
# - **RM** - average number of rooms per dwelling
# - **AGE** - proportion of owner-occupied units built prior to 1940
# - **DIS** - weighted distances to five Boston employment centres
# - **RAD** - index of accessibility to radial highways
# - **TAX** - full-value property-tax rate per $10,000
# - **PTRATIO** - pupil-teacher ratio by town
# - **B** - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - **LSTAT** - % lower status of the population
# - **MEDV** - Median value of owner-occupied homes in $1000's

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"F:\Xaviers Books\Sem 2\Predictive\Practical\Predictive-Analysis-Assignments\datasets\Boston.csv")
df.head(10)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5           6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6           7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7           8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8           9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9          10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# > ### Problem Set 1: An Introduction

# %% [markdown]
# 1. *Report the “class” of the data set. How many rows and columns are in this data set? What do the rows and columns represent?*

# %%
df.shape
# Out:
# (506, 15)

# %% [markdown]
# - It  is a supervised regression dataset
# - The dataset has 506 rows and 15 columns.
# - Each row represents on suburb
# - Each column represents the charecteristics of the suburb

# %% [markdown]
# 2. *Create a smaller data set with the variables median value of owner-occupied
# homes, per capita crime rate, nitrogen oxides concentration, proportion of
# blacks and percentage of lower status of the population. Choosing median
# value of owner occupied homes as the response and the rest as the pre
# dictors, make scatter plots of the response versus each predictor. Present
# the scatter plots in different panels of the same graph. Comment on your
# findings.*

# %%
new_df = df[['crim','nox','black','lstat','medv']]

# %%
new_df.head()
# Out:
#       crim    nox   black  lstat  medv
# 0  0.00632  0.538  396.90   4.98  24.0
# 1  0.02731  0.469  396.90   9.14  21.6
# 2  0.02729  0.469  392.83   4.03  34.7
# 3  0.03237  0.458  394.63   2.94  33.4
# 4  0.06905  0.458  396.90   5.33  36.2

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.scatter(df['crim'],df['medv'])
plt.xlabel('Per Capita Crime Rate (CRIM)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('MEDV vs CRIM')


plt.subplot(2,2,2)
plt.scatter(df['nox'],df['medv'])
plt.xlabel('Nitrogen Oxides Concentration (NOX)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('MEDV vs NOX')



plt.subplot(2,2,3)
plt.scatter(df['black'],df['medv'])
plt.xlabel('Proportion of Blacks (B)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('MEDV vs B')


plt.subplot(2,2,4)
plt.scatter(df['lstat'],df['medv'])
plt.xlabel('Lower Status Population (%) (LSTAT)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('MEDV vs LSTAT')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Comments on the graph
# **MEDV vs CRIM**
# - Clear downward tendency with extreme right-skew.
# - High-crim areas cluster at low house values,but low crim does not gurantee high prices
#
# **MEDV vs NOX**
# - Negetive association.
# - Pollution correlates with lower house prices.
#
# **MEDV vs B**
# - Week and noisy relationship
#
#
# **MEDV VS LSTAT**
# - Strong curved negetive relation
# - As lower-status population increases, house prices drop sharpl

# %% [markdown]
# 3. *Which suburb of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors mentioned in (2), for that suburb. How do these values compare to the overall ranges for those predictors? Comment on your findings. Hint: Mention which percentile these values belong to.*

# %%
# Suburb with lowest median value of owner-occupied homes
lowest_suburb = df[df['medv'] == (df['medv'].min())]
lowest_suburb
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio   black  lstat  medv
# 398  666     20.2  396.90  30.59   5.0
# 405  666     20.2  384.97  22.98   5.0

# %% [markdown]
# *the lowest MEDV= 5.0 , there are more than suburb share the minimum MEDV*

# %%
# values of the other predictors mentioned in (2)
predictors = ['crim','nox','black','lstat']
lowest_suburb[predictors]
# Out:
#         crim    nox   black  lstat
# 398  38.3518  0.693  396.90  30.59
# 405  67.9208  0.693  384.97  22.98

# %% [markdown]
# 4. *Does any suburb of Boston stand out for having notably high crime rates,tax rates, or pupil–teacher ratios? Hint: Use a boxplot to detect any outliers. If so, identify the suburbs that show the outlier values.*

# %%
# Detect outliers using boxplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

variables = ["crim", "tax", "ptratio"]

for ax, var in zip(axes, variables):
    ax.boxplot(df[var])
    ax.set_title(f"Boxplot of {var}")
    ax.set_ylabel(var)

plt.tight_layout()
plt.show()
